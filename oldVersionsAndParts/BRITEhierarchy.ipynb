# %% [markdown]
# ##Group the compounds into the BRITE hierarchy...want to see how the different Kmeans groups do or do not fit with the BRITE hierarchy
# Krista, 1 September 2015
# Modify, 30 November 2015 to get the pathway BRITE hierarchy

# %% [markdown]
# This would probably make more sense as a script, but I did not bother to convert it. Will spit out a pickled file for other use.

# %%
import pandas as pd
import re
import glob
import cPickle as cpk

from IPython.core.debugger import Tracer #used this to step into the function and debug it, also need line with Tracer()()

# %% [markdown]
# Now go in a read one BRITE file (originally for the compounds)

# %%
textC = re.compile('\d+')
mc = textC.search(line)
mc.group(0)
#so, now I have the map number...how do I get the rest of the line?
# Out:
# '01100'

# %%
textC = re.compile(r'(\d+)\s*(.*)$')
mC = textC.search(line)
print mC.group(1)
print mC.group(2)
# Out:
# 01100
# Metabolic pathways

# %%
def ReadBRITEfile(briteFile):
    forBrite = pd.DataFrame(columns = ['map','A','B','C','wholeThing'])
    # set up the expressions to match each level in the BRITE hierarchy
    
    textA = re.compile(r'(^A<b>)(.+)(</b>)\s*(.*)$')
    textB = re.compile(r'(^B)\s*(.*)$')
    textC = re.compile(r'(\d+)\s*(.*)$')
    #this relies on the fact that the rows are in order: A, with B subheadings, then C subheadings
    setA = []
    idxA = []

    setB = []
    setC = []

    with open(briteFile) as f:
        for idx,line in enumerate(f):
            if line[0] is not '#': #skip over the comments
                mA = textA.search(line) 
                mB = textB.search(line) 
                mC = textC.search(line) 
                if mA:
                    setA = mA.group(2)
                    #house cleaning (probably c)
                    idxA = idx
                    forBrite.loc[idx,'A'] = setA
                    forBrite.loc[idx,'wholeThing'] = line #using this as a double check for now
                    #forBrite.loc[idx,'map'] = mC.group(1)
                elif mB:
                    setB = mB.group(2)
                    forBrite.loc[idx,'A'] = setA
                    forBrite.loc[idx,'B'] = setB
                    forBrite.loc[idx,'wholeThing'] = line
                    #forBrite.loc[idx,'map'] = mC.group(1)
                elif mC:
                    #Tracer()()
                    setC = mC.group(2)
                    forBrite.loc[idx,'A'] = setA
                    forBrite.loc[idx,'B'] = setB
                    forBrite.loc[idx,'C'] = setC
                    forBrite.loc[idx,'wholeThing'] = line
                    forBrite.loc[idx,'map'] = mC.group(1)

        return forBrite

# %%
D = glob.glob('*keg.txt')
allBRITE=[]
for idx,nof in enumerate(D):
    allBRITE = ReadBRITEfile(nof)

# %%
type(allBRITE)
# Out:
# pandas.core.frame.DataFrame

# %%
allBRITE.loc[allBRITE['map']=='01100']
# Out:
#       map           A                         B                   C  \
# 10  01100  Metabolism  Global and overview maps  Metabolic pathways
#
#                           wholeThing
# 10  C    01100  Metabolic pathways\n

# %%
allBRITE.loc[allBRITE['map']=='01100'].C
# Out:
# 10    Metabolic pathways
# Name: C, dtype: object

# %%
type(allBRITE.loc[allBRITE['map']=='01100'].C)
# Out:
# pandas.core.series.Series

# %%
allBRITE
# Out:
#        map                 A                                               B  \
# 8      NaN        Metabolism                                             NaN
# 9      NaN        Metabolism                        Global and overview maps
# 10   01100        Metabolism                        Global and overview maps
# 11   01110        Metabolism                        Global and overview maps
# 12   01120        Metabolism                        Global and overview maps
# 13   01130        Metabolism                        Global and overview maps
# 14   01200        Metabolism                        Global and overview maps
# 15   01210        Metabolism                        Global and overview maps
# 16   01212        Metabolism                        Global and overview maps
# 17   01230        Metabolism                        Global and overview maps
# 18   01220        Metabolism                        Global and overview maps
# 19     NaN        Metabolism                         Carbohydrate metabolism
# 20   00010        Metabolism                         Carbohydrate metabolism
# 21   00020        Metabolism                         Carbohydrate metabolism
# 22   00030        Metabolism                         Carbohydrate metabolism
# 23   00040        Metabolism                         Carbohydrate metabolism
# 24   00051        Metabolism                         Carbohydrate metabolism
# 25   00052        Metabolism                         Carbohydrate metabolism
# 26   00053        Metabolism                         Carbohydrate metabolism
# 27   00500        Metabolism                         Carbohydrate metabolism
# 28   00520        Metabolism                         Carbohydrate metabolism
# 29   00620        Metabolism                         Carbohydrate metabolism
# 30   00630        Metabolism                         Carbohydrate metabolism
# 31   00640        Metabolism                         Carbohydrate metabolism
# 32   00650        Metabolism                         Carbohydrate metabolism
# 33   00660        Metabolism                         Carbohydrate metabolism
# 34   00562        Metabolism                         Carbohydrate metabolism
# 35     NaN        Metabolism                               Energy metabolism
# 36   00190        Metabolism                               Energy metabolism
# 37   00195        Metabolism                               Energy metabolism
# ..     ...               ...                                             ...
# 525    NaN  Drug Development  Target-based classification: Nuclear receptors
# 526  07225  Drug Development  Target-based classification: Nuclear receptors
# 527  07226  Drug Development  Target-based classification: Nuclear receptors
# 528  07223  Drug Development  Target-based classification: Nuclear receptors
# 529  07222  Drug Development  Target-based classification: Nuclear receptors
# 530    NaN  Drug Development       Target-based classification: Ion channels
# 531  07221  Drug Development       Target-based classification: Ion channels
# 532  07230  Drug Development       Target-based classification: Ion channels
# 533  07036  Drug Development       Target-based classification: Ion channels
# 534  07231  Drug Development       Target-based classification: Ion channels
# 535  07232  Drug Development       Target-based classification: Ion channels
# 536  07235  Drug Development       Target-based classification: Ion channels
# 537    NaN  Drug Development       Target-based classification: Transporters
# 538  07233  Drug Development       Target-based classification: Transporters
# 539  07234  Drug Development       Target-based classification: Transporters
# 540    NaN  Drug Development            Target-based classification: Enzymes
# 541  07216  Drug Development            Target-based classification: Enzymes
# 542  07219  Drug Development            Target-based classification: Enzymes
# 543  07024  Drug Development            Target-based classification: Enzymes
# 544  07217  Drug Development            Target-based classification: Enzymes
# 545  07218  Drug Development            Target-based classification: Enzymes
# 546    NaN  Drug Development                  Structure-based classification
# 547  07025  Drug Development                  Structure-based classification
# 548  07034  Drug Development                  Structure-based classification
# 549  07035  Drug Development                  Structure-based classification
# 550    NaN  Drug Development                   Skeleton-based classification
# 551  07110  Drug Development                   Skeleton-based classification
# 552  07112  Drug Development                   Skeleton-based classification
# 553  07114  Drug Development                   Skeleton-based classification
# 554  07117  Drug Development                   Skeleton-based classification
#
#                                                      C  \
# 8                                                  NaN
# 9                                                  NaN
# 10                                  Metabolic pathways
# 11               Biosynthesis of secondary metabolites
# 12        Microbial metabolism in diverse environments
# 13                         Biosynthesis of antibiotics
# 14                                   Carbon metabolism
# 15                     2-Oxocarboxylic acid metabolism
# 16                               Fatty acid metabolism
# 17                         Biosynthesis of amino acids
# 18                   Degradation of aromatic compounds
# 19                                                 NaN
# 20                        Glycolysis / Gluconeogenesis
# 21                           Citrate cycle (TCA cycle)
# 22                           Pentose phosphate pathway
# 23            Pentose and glucuronate interconversions
# 24                     Fructose and mannose metabolism
# 25                                Galactose metabolism
# 26                   Ascorbate and aldarate metabolism
# 27                       Starch and sucrose metabolism
# 28         Amino sugar and nucleotide sugar metabolism
# 29                                 Pyruvate metabolism
# 30             Glyoxylate and dicarboxylate metabolism
# 31                               Propanoate metabolism
# 32                                Butanoate metabolism
# 33                 C5-Branched dibasic acid metabolism
# 34                       Inositol phosphate metabolism
# 35                                                 NaN
# 36                           Oxidative phosphorylation
# 37                                      Photosynthesis
# ..                                                 ...
# 525                                                NaN
# 526  Glucocorticoid and meneralocorticoid receptor ...
# 527  Progesterone, androgen and estrogen receptor a...
# 528  Retinoic acid receptor (RAR) and retinoid X re...
# 529  Peroxisome proliferator-activated receptor (PP...
# 530                                                NaN
# 531         Nicotinic cholinergic receptor antagonists
# 532               GABA-A receptor agonists/antagonists
# 533                     Calcium channel blocking drugs
# 534                      Sodium channel blocking drugs
# 535       Potassium channel blocking and opening drugs
# 536       N-Metyl-D-aspartic acid receptor antagonists
# 537                                                NaN
# 538                         Ion transporter inhibitors
# 539            Neurotransmitter transporter inhibitors
# 540                                                NaN
# 541               Catecholamine transferase inhibitors
# 542                          Cyclooxygenase inhibitors
# 543                       HMG-CoA reductase inhibitors
# 544                Renin-angiotensin system inhibitors
# 545                            HIV protease inhibitors
# 546                                                NaN
# 547                                         Quinolines
# 548                                        Eicosanoids
# 549                                     Prostaglandins
# 550                                                NaN
# 551                                Benzoic acid family
# 552                   1,2-Diphenyl substitution family
# 553                                 Naphthalene family
# 554                              Benzodiazepine family
#
#                                             wholeThing
# 8                                 A<b>Metabolism</b>\n
# 9                        B  Global and overview maps\n
# 10                    C    01100  Metabolic pathways\n
# 11   C    01110  Biosynthesis of secondary metaboli...
# 12   C    01120  Microbial metabolism in diverse en...
# 13           C    01130  Biosynthesis of antibiotics\n
# 14                     C    01200  Carbon metabolism\n
# 15       C    01210  2-Oxocarboxylic acid metabolism\n
# 16                 C    01212  Fatty acid metabolism\n
# 17           C    01230  Biosynthesis of amino acids\n
# 18     C    01220  Degradation of aromatic compounds\n
# 19                        B  Carbohydrate metabolism\n
# 20          C    00010  Glycolysis / Gluconeogenesis\n
# 21             C    00020  Citrate cycle (TCA cycle)\n
# 22             C    00030  Pentose phosphate pathway\n
# 23   C    00040  Pentose and glucuronate interconve...
# 24       C    00051  Fructose and mannose metabolism\n
# 25                  C    00052  Galactose metabolism\n
# 26     C    00053  Ascorbate and aldarate metabolism\n
# 27         C    00500  Starch and sucrose metabolism\n
# 28   C    00520  Amino sugar and nucleotide sugar m...
# 29                   C    00620  Pyruvate metabolism\n
# 30   C    00630  Glyoxylate and dicarboxylate metab...
# 31                 C    00640  Propanoate metabolism\n
# 32                  C    00650  Butanoate metabolism\n
# 33   C    00660  C5-Branched dibasic acid metabolism\n
# 34         C    00562  Inositol phosphate metabolism\n
# 35                              B  Energy metabolism\n
# 36             C    00190  Oxidative phosphorylation\n
# 37                        C    00195  Photosynthesis\n
# ..                                                 ...
# 525  B  Target-based classification: Nuclear recept...
# 526  C    07225  Glucocorticoid and meneralocortico...
# 527  C    07226  Progesterone, androgen and estroge...
# 528  C    07223  Retinoic acid receptor (RAR) and r...
# 529  C    07222  Peroxisome proliferator-activated ...
# 530     B  Target-based classification: Ion channels\n
# 531  C    07221  Nicotinic cholinergic receptor ant...
# 532  C    07230  GABA-A receptor agonists/antagonis...
# 533       C    07036  Calcium channel blocking drugs\n
# 534        C    07231  Sodium channel blocking drugs\n
# 535  C    07232  Potassium channel blocking and ope...
# 536  C    07235  N-Metyl-D-aspartic acid receptor a...
# 537     B  Target-based classification: Transporters\n
# 538           C    07233  Ion transporter inhibitors\n
# 539  C    07234  Neurotransmitter transporter inhib...
# 540          B  Target-based classification: Enzymes\n
# 541  C    07216  Catecholamine transferase inhibito...
# 542            C    07219  Cyclooxygenase inhibitors\n
# 543         C    07024  HMG-CoA reductase inhibitors\n
# 544  C    07217  Renin-angiotensin system inhibitors\n
# 545              C    07218  HIV protease inhibitors\n
# 546                B  Structure-based classification\n
# 547                           C    07025  Quinolines\n
# 548                          C    07034  Eicosanoids\n
# 549                       C    07035  Prostaglandins\n
# 550                 B  Skeleton-based classification\n
# 551                  C    07110  Benzoic acid family\n
# 552     C    07112  1,2-Diphenyl substitution family\n
# 553                   C    07114  Naphthalene family\n
# 554                C    07117  Benzodiazepine family\n
#
# [541 rows x 5 columns]

# %%
#now...save all that so I don't have to do this everytime
cpk.dump(allBRITE, open('BRITE_pathwaysOnly.pickle', 'wb'))

# %%
cpk.load(open('BRITE_pathwaysOnly.pickle','rb'))
# Out:
#        map                 A                                               B  \
# 8      NaN        Metabolism                                             NaN
# 9      NaN        Metabolism                        Global and overview maps
# 10   01100        Metabolism                        Global and overview maps
# 11   01110        Metabolism                        Global and overview maps
# 12   01120        Metabolism                        Global and overview maps
# 13   01130        Metabolism                        Global and overview maps
# 14   01200        Metabolism                        Global and overview maps
# 15   01210        Metabolism                        Global and overview maps
# 16   01212        Metabolism                        Global and overview maps
# 17   01230        Metabolism                        Global and overview maps
# 18   01220        Metabolism                        Global and overview maps
# 19     NaN        Metabolism                         Carbohydrate metabolism
# 20   00010        Metabolism                         Carbohydrate metabolism
# 21   00020        Metabolism                         Carbohydrate metabolism
# 22   00030        Metabolism                         Carbohydrate metabolism
# 23   00040        Metabolism                         Carbohydrate metabolism
# 24   00051        Metabolism                         Carbohydrate metabolism
# 25   00052        Metabolism                         Carbohydrate metabolism
# 26   00053        Metabolism                         Carbohydrate metabolism
# 27   00500        Metabolism                         Carbohydrate metabolism
# 28   00520        Metabolism                         Carbohydrate metabolism
# 29   00620        Metabolism                         Carbohydrate metabolism
# 30   00630        Metabolism                         Carbohydrate metabolism
# 31   00640        Metabolism                         Carbohydrate metabolism
# 32   00650        Metabolism                         Carbohydrate metabolism
# 33   00660        Metabolism                         Carbohydrate metabolism
# 34   00562        Metabolism                         Carbohydrate metabolism
# 35     NaN        Metabolism                               Energy metabolism
# 36   00190        Metabolism                               Energy metabolism
# 37   00195        Metabolism                               Energy metabolism
# ..     ...               ...                                             ...
# 525    NaN  Drug Development  Target-based classification: Nuclear receptors
# 526  07225  Drug Development  Target-based classification: Nuclear receptors
# 527  07226  Drug Development  Target-based classification: Nuclear receptors
# 528  07223  Drug Development  Target-based classification: Nuclear receptors
# 529  07222  Drug Development  Target-based classification: Nuclear receptors
# 530    NaN  Drug Development       Target-based classification: Ion channels
# 531  07221  Drug Development       Target-based classification: Ion channels
# 532  07230  Drug Development       Target-based classification: Ion channels
# 533  07036  Drug Development       Target-based classification: Ion channels
# 534  07231  Drug Development       Target-based classification: Ion channels
# 535  07232  Drug Development       Target-based classification: Ion channels
# 536  07235  Drug Development       Target-based classification: Ion channels
# 537    NaN  Drug Development       Target-based classification: Transporters
# 538  07233  Drug Development       Target-based classification: Transporters
# 539  07234  Drug Development       Target-based classification: Transporters
# 540    NaN  Drug Development            Target-based classification: Enzymes
# 541  07216  Drug Development            Target-based classification: Enzymes
# 542  07219  Drug Development            Target-based classification: Enzymes
# 543  07024  Drug Development            Target-based classification: Enzymes
# 544  07217  Drug Development            Target-based classification: Enzymes
# 545  07218  Drug Development            Target-based classification: Enzymes
# 546    NaN  Drug Development                  Structure-based classification
# 547  07025  Drug Development                  Structure-based classification
# 548  07034  Drug Development                  Structure-based classification
# 549  07035  Drug Development                  Structure-based classification
# 550    NaN  Drug Development                   Skeleton-based classification
# 551  07110  Drug Development                   Skeleton-based classification
# 552  07112  Drug Development                   Skeleton-based classification
# 553  07114  Drug Development                   Skeleton-based classification
# 554  07117  Drug Development                   Skeleton-based classification
#
#                                                      C  \
# 8                                                  NaN
# 9                                                  NaN
# 10                                  Metabolic pathways
# 11               Biosynthesis of secondary metabolites
# 12        Microbial metabolism in diverse environments
# 13                         Biosynthesis of antibiotics
# 14                                   Carbon metabolism
# 15                     2-Oxocarboxylic acid metabolism
# 16                               Fatty acid metabolism
# 17                         Biosynthesis of amino acids
# 18                   Degradation of aromatic compounds
# 19                                                 NaN
# 20                        Glycolysis / Gluconeogenesis
# 21                           Citrate cycle (TCA cycle)
# 22                           Pentose phosphate pathway
# 23            Pentose and glucuronate interconversions
# 24                     Fructose and mannose metabolism
# 25                                Galactose metabolism
# 26                   Ascorbate and aldarate metabolism
# 27                       Starch and sucrose metabolism
# 28         Amino sugar and nucleotide sugar metabolism
# 29                                 Pyruvate metabolism
# 30             Glyoxylate and dicarboxylate metabolism
# 31                               Propanoate metabolism
# 32                                Butanoate metabolism
# 33                 C5-Branched dibasic acid metabolism
# 34                       Inositol phosphate metabolism
# 35                                                 NaN
# 36                           Oxidative phosphorylation
# 37                                      Photosynthesis
# ..                                                 ...
# 525                                                NaN
# 526  Glucocorticoid and meneralocorticoid receptor ...
# 527  Progesterone, androgen and estrogen receptor a...
# 528  Retinoic acid receptor (RAR) and retinoid X re...
# 529  Peroxisome proliferator-activated receptor (PP...
# 530                                                NaN
# 531         Nicotinic cholinergic receptor antagonists
# 532               GABA-A receptor agonists/antagonists
# 533                     Calcium channel blocking drugs
# 534                      Sodium channel blocking drugs
# 535       Potassium channel blocking and opening drugs
# 536       N-Metyl-D-aspartic acid receptor antagonists
# 537                                                NaN
# 538                         Ion transporter inhibitors
# 539            Neurotransmitter transporter inhibitors
# 540                                                NaN
# 541               Catecholamine transferase inhibitors
# 542                          Cyclooxygenase inhibitors
# 543                       HMG-CoA reductase inhibitors
# 544                Renin-angiotensin system inhibitors
# 545                            HIV protease inhibitors
# 546                                                NaN
# 547                                         Quinolines
# 548                                        Eicosanoids
# 549                                     Prostaglandins
# 550                                                NaN
# 551                                Benzoic acid family
# 552                   1,2-Diphenyl substitution family
# 553                                 Naphthalene family
# 554                              Benzodiazepine family
#
#                                             wholeThing
# 8                                 A<b>Metabolism</b>\n
# 9                        B  Global and overview maps\n
# 10                    C    01100  Metabolic pathways\n
# 11   C    01110  Biosynthesis of secondary metaboli...
# 12   C    01120  Microbial metabolism in diverse en...
# 13           C    01130  Biosynthesis of antibiotics\n
# 14                     C    01200  Carbon metabolism\n
# 15       C    01210  2-Oxocarboxylic acid metabolism\n
# 16                 C    01212  Fatty acid metabolism\n
# 17           C    01230  Biosynthesis of amino acids\n
# 18     C    01220  Degradation of aromatic compounds\n
# 19                        B  Carbohydrate metabolism\n
# 20          C    00010  Glycolysis / Gluconeogenesis\n
# 21             C    00020  Citrate cycle (TCA cycle)\n
# 22             C    00030  Pentose phosphate pathway\n
# 23   C    00040  Pentose and glucuronate interconve...
# 24       C    00051  Fructose and mannose metabolism\n
# 25                  C    00052  Galactose metabolism\n
# 26     C    00053  Ascorbate and aldarate metabolism\n
# 27         C    00500  Starch and sucrose metabolism\n
# 28   C    00520  Amino sugar and nucleotide sugar m...
# 29                   C    00620  Pyruvate metabolism\n
# 30   C    00630  Glyoxylate and dicarboxylate metab...
# 31                 C    00640  Propanoate metabolism\n
# 32                  C    00650  Butanoate metabolism\n
# 33   C    00660  C5-Branched dibasic acid metabolism\n
# 34         C    00562  Inositol phosphate metabolism\n
# 35                              B  Energy metabolism\n
# 36             C    00190  Oxidative phosphorylation\n
# 37                        C    00195  Photosynthesis\n
# ..                                                 ...
# 525  B  Target-based classification: Nuclear recept...
# 526  C    07225  Glucocorticoid and meneralocortico...
# 527  C    07226  Progesterone, androgen and estroge...
# 528  C    07223  Retinoic acid receptor (RAR) and r...
# 529  C    07222  Peroxisome proliferator-activated ...
# 530     B  Target-based classification: Ion channels\n
# 531  C    07221  Nicotinic cholinergic receptor ant...
# 532  C    07230  GABA-A receptor agonists/antagonis...
# 533       C    07036  Calcium channel blocking drugs\n
# 534        C    07231  Sodium channel blocking drugs\n
# 535  C    07232  Potassium channel blocking and ope...
# 536  C    07235  N-Metyl-D-aspartic acid receptor a...
# 537     B  Target-based classification: Transporters\n
# 538           C    07233  Ion transporter inhibitors\n
# 539  C    07234  Neurotransmitter transporter inhib...
# 540          B  Target-based classification: Enzymes\n
# 541  C    07216  Catecholamine transferase inhibito...
# 542            C    07219  Cyclooxygenase inhibitors\n
# 543         C    07024  HMG-CoA reductase inhibitors\n
# 544  C    07217  Renin-angiotensin system inhibitors\n
# 545              C    07218  HIV protease inhibitors\n
# 546                B  Structure-based classification\n
# 547                           C    07025  Quinolines\n
# 548                          C    07034  Eicosanoids\n
# 549                       C    07035  Prostaglandins\n
# 550                 B  Skeleton-based classification\n
# 551                  C    07110  Benzoic acid family\n
# 552     C    07112  1,2-Diphenyl substitution family\n
# 553                   C    07114  Naphthalene family\n
# 554                C    07117  Benzodiazepine family\n
#
# [541 rows x 5 columns]
